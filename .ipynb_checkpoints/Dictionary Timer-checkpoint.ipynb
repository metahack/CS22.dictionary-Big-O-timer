# %%
# Earle Bowers CS22 F14 LBCC
# This program confirms that dictionary get and set are constant time operations

import timeit
import random

test_counts = []
test_set_data = []
test_get_data = []

def test_set(dict_to_use, i):
    dict_to_use[i] = True

def test_get(dict_to_use, i):
    return dict_to_use[i]

#EZ range = 100,000 to 5,000,000 in steps of 100,000
for i in range(100 * 1000, 5000 * 1000 + 1, 100 * 1000):

    dictionary = {}
    for x in range(0,i):
        dictionary[x] = False
        
    rand = random.randint(0,i)

    s = timeit.Timer('test_set(dictionary, %i)' % rand, 'from __main__ import test_set, dictionary')
    set_time = s.timeit()

    rand = random.randint(0,i)

    g = timeit.Timer('test_get(dictionary, %i)' % rand, 'from __main__ import test_get, dictionary')
    get_time = g.timeit()

    test_counts.append(i)
    test_set_data.append(set_time)
    test_get_data.append(get_time)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random', 'rand']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
pylab.figure(figsize=(24, 12))
pylab.title('SET operation on dictionaries')
pylab.ylabel('duration (secs) for 1 million runs')
pylab.xlabel('# of elements in dictionary')
pylab.ylim([0,1])
pylab.scatter(test_counts, test_set_data, color="red")

# %%
pylab.figure(figsize=(24, 12))
pylab.title('GET operation on dictionaries')
pylab.ylabel('duration (secs) for 1 million runs')
pylab.xlabel('# of elements in dictionary')
pylab.ylim([0,1])
pylab.scatter(test_counts, test_get_data)

# %%
print('     N\t         "set"\t   "get"\n')
for i in range(len(test_counts)):
    print('{:9,.0f}\t{:.5f}\t  {:.5f}\n'.format(test_counts[i], test_set_data[i], test_get_data[i]))
# Out:
#      N	         "set"	   "get"
#
#   100,000	0.67792	  0.53876
#
#   200,000	0.67446	  0.55591
#
#   300,000	0.67430	  0.54879
#
#   400,000	0.67195	  0.54795
#
#   500,000	0.67337	  0.54374
#
#   600,000	0.67113	  0.54672
#
#   700,000	0.67258	  0.54120
#
#   800,000	0.67040	  0.54612
#
#   900,000	0.67637	  0.54336
#
# 1,000,000	0.67376	  0.54394
#
# 1,100,000	0.66958	  0.54213
#
# 1,200,000	0.66862	  0.53948
#
# 1,300,000	0.67119	  0.54449
#
# 1,400,000	0.67395	  0.54938
#
# 1,500,000	0.67043	  0.54264
#
# 1,600,000	0.66881	  0.54141
#
# 1,700,000	0.67085	  0.54825
#
# 1,800,000	0.67165	  0.55095
#
# 1,900,000	0.66831	  0.54468
#
# 2,000,000	0.66996	  0.54432
#
# 2,100,000	0.67309	  0.54134
#
# 2,200,000	0.67180	  0.55159
#
# 2,300,000	0.67049	  0.54154
#
# 2,400,000	0.66995	  0.54416
#
# 2,500,000	0.67205	  0.54171
#
# 2,600,000	0.66930	  0.54535
#
# 2,700,000	0.67051	  0.54220
#
# 2,800,000	0.66959	  0.54661
#
# 2,900,000	0.66925	  0.54922
#
# 3,000,000	0.66904	  0.55132
#
# 3,100,000	0.67067	  0.54612
#
# 3,200,000	0.67036	  0.54541
#
# 3,300,000	0.66891	  0.55141
#
# 3,400,000	0.67286	  0.54868
#
# 3,500,000	0.66912	  0.55073
#
# 3,600,000	0.67112	  0.54288
#
# 3,700,000	0.66859	  0.55217
#
# 3,800,000	0.67078	  0.54219
#
# 3,900,000	0.67400	  0.53912
#
# 4,000,000	0.66995	  0.54009
#
# 4,100,000	0.67031	  0.53749
#
# 4,200,000	0.69024	  0.55999
#
# 4,300,000	0.68384	  0.55971
#
# 4,400,000	0.68084	  0.57765
#
# 4,500,000	0.67850	  0.55549
#
# 4,600,000	0.68063	  0.53889
#
# 4,700,000	0.67400	  0.54381
#
# 4,800,000	0.67228	  0.54388
#
# 4,900,000	0.67494	  0.54781
#
# 5,000,000	0.67301	  0.54968
